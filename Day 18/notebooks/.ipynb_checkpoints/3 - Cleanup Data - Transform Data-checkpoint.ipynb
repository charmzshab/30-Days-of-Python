# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() # dirname(abspath(__file__)) jupyter notebook doesn't support __file__

# %%
BASE_DIR = os.path.dirname(cwd)
DATA_DIR = os.path.join(BASE_DIR,"data")
CACHE_DIR = os.path.join(BASE_DIR,"cache")
working_file = os.path.join(CACHE_DIR,"movies-box-office-dataset.csv")
output_file = os.path.join(CACHE_DIR,"movies-box-office-dataset-cleaned.csv")

# %%
df = pd.read_csv(working_file)

# %%
df.shape
# Out:
# (10110, 8)

# %%
df.head(1200) # Rank isn't matching with the count of observations
# Out:
#       Rank           Release Group     Worldwide      Domestic      %  \
# 0        1  Mission: Impossible II  $546,388,108  $215,409,889  39.4%
# 1        2               Gladiator  $460,583,960  $187,705,427  40.8%
# 2        3               Cast Away  $429,632,142  $233,632,142  54.4%
# 3        4         What Women Want  $374,111,707  $182,811,707  48.9%
# 4        5                Dinosaur  $349,822,765  $137,748,063  39.4%
# ...    ...                     ...           ...           ...    ...
# 1195   414        Girls Can't Swim       $69,250       $69,250   100%
# 1196   415                   Bundy       $68,716        $6,073   8.8%
# 1197   416            Spooky House       $65,238       $65,238   100%
# 1198   417         Gaudi Afternoon       $65,115        $5,858     9%
# 1199   418             Just a Kiss       $64,389       $64,389   100%
#
#            Foreign    %.1  Year
# 0     $330,978,219  60.6%  2000
# 1     $272,878,533  59.2%  2000
# 2     $196,000,000  45.6%  2000
# 3     $191,300,000  51.1%  2000
# 4     $212,074,702  60.6%  2000
# ...            ...    ...   ...
# 1195             -      -  2002
# 1196       $62,643  91.2%  2002
# 1197             -      -  2002
# 1198       $59,257    91%  2002
# 1199             -      -  2002
#
# [1200 rows x 8 columns]

# %%
df['Rank'] = -1

# %%
df.head()
# Out:
#    Rank           Release Group     Worldwide      Domestic      %  \
# 0    -1  Mission: Impossible II  $546,388,108  $215,409,889  39.4%
# 1    -1               Gladiator  $460,583,960  $187,705,427  40.8%
# 2    -1               Cast Away  $429,632,142  $233,632,142  54.4%
# 3    -1         What Women Want  $374,111,707  $182,811,707  48.9%
# 4    -1                Dinosaur  $349,822,765  $137,748,063  39.4%
#
#         Foreign    %.1  Year
# 0  $330,978,219  60.6%  2000
# 1  $272,878,533  59.2%  2000
# 2  $196,000,000  45.6%  2000
# 3  $191,300,000  51.1%  2000
# 4  $212,074,702  60.6%  2000

# %%
df['Domestic %'] = df['%']
df['Foreign %'] = df['%.1']

# %%
df.head()
# Out:
#    Rank           Release Group     Worldwide      Domestic      %  \
# 0    -1  Mission: Impossible II  $546,388,108  $215,409,889  39.4%
# 1    -1               Gladiator  $460,583,960  $187,705,427  40.8%
# 2    -1               Cast Away  $429,632,142  $233,632,142  54.4%
# 3    -1         What Women Want  $374,111,707  $182,811,707  48.9%
# 4    -1                Dinosaur  $349,822,765  $137,748,063  39.4%
#
#         Foreign    %.1  Year Domestic % Foreign %
# 0  $330,978,219  60.6%  2000      39.4%     60.6%
# 1  $272,878,533  59.2%  2000      40.8%     59.2%
# 2  $196,000,000  45.6%  2000      54.4%     45.6%
# 3  $191,300,000  51.1%  2000      48.9%     51.1%
# 4  $212,074,702  60.6%  2000      39.4%     60.6%

# %%
df.drop(columns=['%','%.1'],inplace=True)

# %%
df.head()
# Out:
#    Rank           Release Group     Worldwide      Domestic       Foreign  \
# 0    -1  Mission: Impossible II  $546,388,108  $215,409,889  $330,978,219
# 1    -1               Gladiator  $460,583,960  $187,705,427  $272,878,533
# 2    -1               Cast Away  $429,632,142  $233,632,142  $196,000,000
# 3    -1         What Women Want  $374,111,707  $182,811,707  $191,300,000
# 4    -1                Dinosaur  $349,822,765  $137,748,063  $212,074,702
#
#    Year Domestic % Foreign %
# 0  2000      39.4%     60.6%
# 1  2000      40.8%     59.2%
# 2  2000      54.4%     45.6%
# 3  2000      48.9%     51.1%
# 4  2000      39.4%     60.6%

# %%
to_clean_cols = ['Worldwide','Domestic','Foreign']

def currency_str_to_int(current_val):
    currency_val = current_val.replace("$","").replace(",","")
    try:
        currency_val = int(currency_val)
    except:
        # Takes any row value with "-" and turns into 0
        currency_val = 0
    return currency_val

def clean_col(row):
    """
    row: Pandas series
    dataframe: colllection of pandas series
    """
    for col in to_clean_cols:
        row[col] = currency_str_to_int(row[col])
    #print(row)
    return row

# %%
df_cleaned = df.apply(clean_col,axis=1)

# %%
df_cleaned.head()
# Out:
#    Rank           Release Group  Worldwide   Domestic    Foreign  Year  \
# 0    -1  Mission: Impossible II  546388108  215409889  330978219  2000
# 1    -1               Gladiator  460583960  187705427  272878533  2000
# 2    -1               Cast Away  429632142  233632142  196000000  2000
# 3    -1         What Women Want  374111707  182811707  191300000  2000
# 4    -1                Dinosaur  349822765  137748063  212074702  2000
#
#   Domestic % Foreign %
# 0      39.4%     60.6%
# 1      40.8%     59.2%
# 2      54.4%     45.6%
# 3      48.9%     51.1%
# 4      39.4%     60.6%

# %%
df_cleaned.dtypes
# Out:
# Rank              int64
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Foreign           int64
# Year              int64
# Domestic %       object
# Foreign %        object
# dtype: object

# %%
df_cleaned.sort_values(by=['Worldwide'],inplace=True,ascending=False)
df_cleaned.head()
# Out:
#       Rank                               Release Group   Worldwide   Domestic  \
# 9387    -1                           Avengers: Endgame  2797800564  858373000
# 6212    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 8487    -1                      Avengers: Infinity War  2048359754  678815482
# 6213    -1                              Jurassic World  1670400637  652270625
# 9388    -1                               The Lion King  1656943394  543638043
#
#          Foreign  Year Domestic % Foreign %
# 9387  1939427564  2019      30.7%     69.3%
# 6212  1131561399  2015      45.3%     54.7%
# 8487  1369544272  2018      33.1%     66.9%
# 6213  1018130012  2015        39%       61%
# 9388  1113305351  2019      32.8%     67.2%

# %%
df_cleaned.reset_index(inplace=True,drop=True)
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0    -1                           Avengers: Endgame  2797800564  858373000
# 1    -1  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2    -1                      Avengers: Infinity War  2048359754  678815482
# 3    -1                              Jurassic World  1670400637  652270625
# 4    -1                               The Lion King  1656943394  543638043
#
#       Foreign  Year Domestic % Foreign %
# 0  1939427564  2019      30.7%     69.3%
# 1  1131561399  2015      45.3%     54.7%
# 2  1369544272  2018      33.1%     66.9%
# 3  1018130012  2015        39%       61%
# 4  1113305351  2019      32.8%     67.2%

# %%
df_cleaned['Rank'] = df_cleaned.index + 1

# %%
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  Year Domestic % Foreign %
# 0  1939427564  2019      30.7%     69.3%
# 1  1131561399  2015      45.3%     54.7%
# 2  1369544272  2018      33.1%     66.9%
# 3  1018130012  2015        39%       61%
# 4  1113305351  2019      32.8%     67.2%

# %%
df_cleaned['Domestic %'] = df_cleaned['Domestic'] / df_cleaned['Worldwide']
df_cleaned['Foreign %'] = df_cleaned['Foreign'] / df_cleaned['Worldwide']

# %%
df_cleaned.head()
# Out:
#    Rank                               Release Group   Worldwide   Domestic  \
# 0     1                           Avengers: Endgame  2797800564  858373000
# 1     2  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 2     3                      Avengers: Infinity War  2048359754  678815482
# 3     4                              Jurassic World  1670400637  652270625
# 4     5                               The Lion King  1656943394  543638043
#
#       Foreign  Year  Domestic %  Foreign %
# 0  1939427564  2019    0.306803   0.693197
# 1  1131561399  2015    0.452882   0.547118
# 2  1369544272  2018    0.331395   0.668605
# 3  1018130012  2015    0.390488   0.609512
# 4  1113305351  2019    0.328097   0.671903

# %%
df_cleaned.to_csv(output_file,index=False)
