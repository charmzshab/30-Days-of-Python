# %%
# !jupyter nbconvert --output-dir='../client' --to python spotify_client.ipynb
# Out:
# [NbConvertApp] Converting notebook spotify_client.ipynb to python
# [NbConvertApp] Writing 4394 bytes to ../client\spotify_client.py
