# %%
from spotify_client import *

# %%
client_id = "c060a698be6449279c07f9f4a3c6e952"
client_secret = "92f9c0d577024d3e85ee90482b268e19"

# %%
spotify = SpotifyAPI(client_id,client_secret)

# %%
spotify.search({"track":"Hope","artist":"Twista"}, search_type="track")
# Out:
# q=track%3AHope+artist%3ATwista&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=track%3AHope+artist%3ATwista&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5NDMothbpdpq2xHqSjrrWn'},
#        'href': 'https://api.spotify.com/v1/artists/5NDMothbpdpq2xHqSjrrWn',
#        'id': '5NDMothbpdpq2xHqSjrrWn',
#        'name': 'Faith Evans',
#        'type': 'artist',
#        'uri': 'spotify:artist:5NDMothbpdpq2xHqSjrrWn'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2WiOKRbyIKKeA8L7IossNX'},
#      'href': 'https://api.spotify.com/v1/albums/2WiOKRbyIKKeA8L7IossNX',
#      'id': '2WiOKRbyIKKeA8L7IossNX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f7287b73d4507876d6c734f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f7287b73d4507876d6c734f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f7287b73d4507876d6c734f',
#        'width': 64}],
#      'name': 'The First Lady',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2WiOKRbyIKKeA8L7IossNX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vbY3hOaCAhC7VjucswgdS'},
#       'href': 'https://api.spotify.com/v1/artists/6vbY3hOaCAhC7VjucswgdS',
#       'id': '6vbY3hOaCAhC7VjucswgdS',
#       'name': 'Twista',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vbY3hOaCAhC7VjucswgdS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5NDMothbpdpq2xHqSjrrWn'},
#       'href': 'https://api.spotify.com/v1/artists/5NDMothbpdpq2xHqSjrrWn',
#       'id': '5NDMothbpdpq2xHqSjrrWn',
#       'name': 'Faith Evans',
#       'type': 'artist',
#       'uri': 'spotify:artist:5NDMothbpdpq2xHqSjrrWn'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 254960,
#     'explicit': True,
#     'external_ids': {'isrc': 'USCA20401355'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2xxx3hyrkpFgrGi6iCVx9y'},
#     'href': 'https://api.spotify.com/v1/tracks/2xxx3hyrkpFgrGi6iCVx9y',
#     'id': '2xxx3hyrkpFgrGi6iCVx9y',
#     'is_local': False,
#     'name': 'Hope',
#     'popularity': 58,
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:2xxx3hyrkpFgrGi6iCVx9y'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vbY3hOaCAhC7VjucswgdS'},
#        'href': 'https://api.spotify.com/v1/artists/6vbY3hOaCAhC7VjucswgdS',
#        'id': '6vbY3hOaCAhC7VjucswgdS',
#        'name': 'Twista',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vbY3hOaCAhC7VjucswgdS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Xu470gdLgDOnFDj5qND1N'},
#      'href': 'https://api.spotify.com/v1/albums/6Xu470gdLgDOnFDj5qND1N',
#      'id': '6Xu470gdLgDOnFDj5qND1N',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397dd7c02036d9ab37d60a2df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297dd7c02036d9ab37d60a2df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197dd7c02036d9ab37d60a2df',
#        'width': 64}],
#      'name': 'Kamikaze',
#      'release_date': '2004-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:6Xu470gdLgDOnFDj5qND1N'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vbY3hOaCAhC7VjucswgdS'},
#       'href': 'https://api.spotify.com/v1/artists/6vbY3hOaCAhC7VjucswgdS',
#       'id': '6vbY3hOaCAhC7VjucswgdS',
#       'name': 'Twista',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vbY3hOaCAhC7VjucswgdS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nLYd9ST4Cnwy6NHaCxbj8'},
#       'href': 'https://api.spotify.com/v1/artists/5nLYd9ST4Cnwy6NHaCxbj8',
#       'id': '5nLYd9ST4Cnwy6NHaCxbj8',
#       'name': 'CeeLo Green',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nLYd9ST4Cnwy6NHaCxbj8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 273053,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT20303729'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69ZsCCgyBTnRwPGrot5oYh'},
#     'href': 'https://api.spotify.com/v1/tracks/69ZsCCgyBTnRwPGrot5oYh',
#     'id': '69ZsCCgyBTnRwPGrot5oYh',
#     'is_local': False,
#     'name': 'Hope (feat. Cee-Lo)',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0db656a02dae67842a853c9c7e7490e9270827a4?cid=c060a698be6449279c07f9f4a3c6e952',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:69ZsCCgyBTnRwPGrot5oYh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vbY3hOaCAhC7VjucswgdS'},
#        'href': 'https://api.spotify.com/v1/artists/6vbY3hOaCAhC7VjucswgdS',
#        'id': '6vbY3hOaCAhC7VjucswgdS',
#        'name': 'Twista',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vbY3hOaCAhC7VjucswgdS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BY',
#       'CA',
#       'CH',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'HR',
#       'HU',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MY',
#       'NL',
#       'NO',
#       'OM',
#       'PL',
#       'PT',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SI',
#       'SK',
#       'TN',
#       'TR',
#       'UA',
#       'US',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7tbgPQub8dUigxMdkYDfOb'},
#      'href': 'https://api.spotify.com/v1/albums/7tbgPQub8dUigxMdkYDfOb',
#      'id': '7tbgPQub8dUigxMdkYDfOb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f9fccd094fd20004223ceb4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f9fccd094fd20004223ceb4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f9fccd094fd20004223ceb4',
#        'width': 64}],
#      'name': 'Kamikaze',
#      'release_date': '2004-01-27',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:7tbgPQub8dUigxMdkYDfOb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vbY3hOaCAhC7VjucswgdS'},
#       'href': 'https://api.spotify.com/v1/artists/6vbY3hOaCAhC7VjucswgdS',
#       'id': '6vbY3hOaCAhC7VjucswgdS',
#       'name': 'Twista',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vbY3hOaCAhC7VjucswgdS'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5nLYd9ST4Cnwy6NHaCxbj8'},
#       'href': 'https://api.spotify.com/v1/artists/5nLYd9ST4Cnwy6NHaCxbj8',
#       'id': '5nLYd9ST4Cnwy6NHaCxbj8',
#       'name': 'CeeLo Green',
#       'type': 'artist',
#       'uri': 'spotify:artist:5nLYd9ST4Cnwy6NHaCxbj8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BY',
#      'CA',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MY',
#      'NL',
#      'NO',
#      'OM',
#      'PL',
#      'PT',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SI',
#      'SK',
#      'TN',
#      'TR',
#      'UA',
#      'US',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 273053,
#     'explicit': True,
#     'external_ids': {'isrc': 'USAT20303729'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xfeavhko9YYavyoIIqr3Q'},
#     'href': 'https://api.spotify.com/v1/tracks/1xfeavhko9YYavyoIIqr3Q',
#     'id': '1xfeavhko9YYavyoIIqr3Q',
#     'is_local': False,
#     'name': 'Hope (feat. Cee-Lo)',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0db656a02dae67842a853c9c7e7490e9270827a4?cid=c060a698be6449279c07f9f4a3c6e952',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:1xfeavhko9YYavyoIIqr3Q'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 3}}
